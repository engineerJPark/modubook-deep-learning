# %%
#데이터 입력
from google.colab import files
uploaded = files.upload()
my_data = 'wine.csv'

# !pip install -q tensorflow-gpu==1.15.0
# %tensorflow_version 1.x
import tensorflow as tf
import pandas as pd
import numpy
import os

from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint,EarlyStopping

# seed 값 설정
numpy.random.seed(3)
tf.compat.v1.set_random_seed(3)

#데이터 적용
df_pre = pd.read_csv(my_data, header=None)
df = df_pre.sample(frac=0.15)

dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

model = Sequential()
model.add(Dense(30,  input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])
# Out:
#      <input type="file" id="files-c4a04940-8e2e-406d-a3ab-d90e7814814e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c4a04940-8e2e-406d-a3ab-d90e7814814e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wine.csv to wine.csv
#      |████████████████████████████████| 411.5MB 25kB/s
#      |████████████████████████████████| 3.8MB 43.4MB/s
#      |████████████████████████████████| 51kB 5.6MB/s
#      |████████████████████████████████| 512kB 53.2MB/s
#   Building wheel for gast (setup.py) ... done
# ERROR: tensorflow 2.5.0 has requirement gast==0.4.0, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.5.0 has requirement tensorboard~=2.5, but you'll have tensorboard 1.15.0 which is incompatible.
# ERROR: tensorflow 2.5.0 has requirement tensorflow-estimator<2.6.0,>=2.5.0rc0, but you'll have tensorflow-estimator 1.15.1 which is incompatible.
# ERROR: tensorflow-probability 0.12.1 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# TensorFlow 1.x selected.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Using TensorFlow backend.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
모델 저장과, 학습 자동중단 기능을 둘다 사용해본다..

# %%
# 모델 저장 폴더 만들기
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"

# 모델 업데이트 및 저장
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

# 학습 자동 중단 설정
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100)

model.fit(X, Y, validation_split=0.2, epochs=3500, batch_size=500, verbose=0, callbacks=[early_stopping_callback,checkpointer])

print("\n Accuracy : %.4f" %(model.evaluate(X,Y)[1]))
# Out:
# Epoch 00001: val_loss improved from inf to 0.06142, saving model to ./model/01-0.0614.hdf5
#
# Epoch 00002: val_loss did not improve from 0.06142
#
# Epoch 00003: val_loss did not improve from 0.06142
#
# Epoch 00004: val_loss did not improve from 0.06142
#
# Epoch 00005: val_loss did not improve from 0.06142
#
# Epoch 00006: val_loss did not improve from 0.06142
#
# Epoch 00007: val_loss did not improve from 0.06142
#
# Epoch 00008: val_loss did not improve from 0.06142
#
# Epoch 00009: val_loss did not improve from 0.06142
#
# Epoch 00010: val_loss improved from 0.06142 to 0.06057, saving model to ./model/10-0.0606.hdf5
#
# Epoch 00011: val_loss improved from 0.06057 to 0.06047, saving model to ./model/11-0.0605.hdf5
#
# Epoch 00012: val_loss did not improve from 0.06047
#
# Epoch 00013: val_loss did not improve from 0.06047
#
# Epoch 00014: val_loss did not improve from 0.06047
#
# Epoch 00015: val_loss did not improve from 0.06047
#
# Epoch 00016: val_loss did not improve from 0.06047
#
# Epoch 00017: val_loss did not improve from 0.06047
#
# Epoch 00018: val_loss improved from 0.06047 to 0.06020, saving model to ./model/18-0.0602.hdf5
#
# Epoch 00019: val_loss improved from 0.06020 to 0.05847, saving model to ./model/19-0.0585.hdf5
#
# Epoch 00020: val_loss did not improve from 0.05847
#
# Epoch 00021: val_loss did not improve from 0.05847
#
# Epoch 00022: val_loss did not improve from 0.05847
#
# Epoch 00023: val_loss did not improve from 0.05847
#
# Epoch 00024: val_loss did not improve from 0.05847
#
# Epoch 00025: val_loss did not improve from 0.05847
#
# Epoch 00026: val_loss did not improve from 0.05847
#
# Epoch 00027: val_loss did not improve from 0.05847
#
# Epoch 00028: val_loss did not improve from 0.05847
#
# Epoch 00029: val_loss did not improve from 0.05847
#
# Epoch 00030: val_loss did not improve from 0.05847
#
# Epoch 00031: val_loss did not improve from 0.05847
#
# Epoch 00032: val_loss did not improve from 0.05847
#
# Epoch 00033: val_loss did not improve from 0.05847
#
# Epoch 00034: val_loss did not improve from 0.05847
#
# Epoch 00035: val_loss did not improve from 0.05847
#
# Epoch 00036: val_loss did not improve from 0.05847
#
# Epoch 00037: val_loss did not improve from 0.05847
#
# Epoch 00038: val_loss did not improve from 0.05847
#
# Epoch 00039: val_loss did not improve from 0.05847
#
# Epoch 00040: val_loss did not improve from 0.05847
#
# Epoch 00041: val_loss did not improve from 0.05847
#
# Epoch 00042: val_loss did not improve from 0.05847
#
# Epoch 00043: val_loss did not improve from 0.05847
#
# Epoch 00044: val_loss did not improve from 0.05847
#
# Epoch 00045: val_loss did not improve from 0.05847
#
# Epoch 00046: val_loss did not improve from 0.05847
#
# Epoch 00047: val_loss did not improve from 0.05847
#
# Epoch 00048: val_loss did not improve from 0.05847
#
# Epoch 00049: val_loss did not improve from 0.05847
#
# Epoch 00050: val_loss did not improve from 0.05847
#
# Epoch 00051: val_loss did not improve from 0.05847
#
# Epoch 00052: val_loss did not improve from 0.05847
#
# Epoch 00053: val_loss did not improve from 0.05847
#
# Epoch 00054: val_loss did not improve from 0.05847
#
# Epoch 00055: val_loss did not improve from 0.05847
#
# Epoch 00056: val_loss did not improve from 0.05847
#
# Epoch 00057: val_loss did not improve from 0.05847
#
# Epoch 00058: val_loss did not improve from 0.05847
#
# Epoch 00059: val_loss did not improve from 0.05847
#
# Epoch 00060: val_loss did not improve from 0.05847
#
# Epoch 00061: val_loss did not improve from 0.05847
#
# Epoch 00062: val_loss did not improve from 0.05847
#
# Epoch 00063: val_loss did not improve from 0.05847
#
# Epoch 00064: val_loss did not improve from 0.05847
#
# Epoch 00065: val_loss did not improve from 0.05847
#
# Epoch 00066: val_loss did not improve from 0.05847
#
# Epoch 00067: val_loss did not improve from 0.05847
#
# Epoch 00068: val_loss did not improve from 0.05847
#
# Epoch 00069: val_loss did not improve from 0.05847
#
# Epoch 00070: val_loss did not improve from 0.05847
#
# Epoch 00071: val_loss did not improve from 0.05847
#
# Epoch 00072: val_loss did not improve from 0.05847
#
# Epoch 00073: val_loss did not improve from 0.05847
#
# Epoch 00074: val_loss did not improve from 0.05847
#
# Epoch 00075: val_loss did not improve from 0.05847
#
# Epoch 00076: val_loss did not improve from 0.05847
#
# Epoch 00077: val_loss did not improve from 0.05847
#
# Epoch 00078: val_loss did not improve from 0.05847
#
# Epoch 00079: val_loss did not improve from 0.05847
#
# Epoch 00080: val_loss did not improve from 0.05847
#
# Epoch 00081: val_loss did not improve from 0.05847
#
# Epoch 00082: val_loss did not improve from 0.05847
#
# Epoch 00083: val_loss did not improve from 0.05847
#
# Epoch 00084: val_loss did not improve from 0.05847
#
# Epoch 00085: val_loss did not improve from 0.05847
#
# Epoch 00086: val_loss did not improve from 0.05847
#
# Epoch 00087: val_loss did not improve from 0.05847
#
# Epoch 00088: val_loss did not improve from 0.05847
#
# Epoch 00089: val_loss did not improve from 0.05847
#
# Epoch 00090: val_loss did not improve from 0.05847
#
# Epoch 00091: val_loss did not improve from 0.05847
#
# Epoch 00092: val_loss did not improve from 0.05847
#
# Epoch 00093: val_loss did not improve from 0.05847
#
# Epoch 00094: val_loss did not improve from 0.05847
#
# Epoch 00095: val_loss did not improve from 0.05847
#
# Epoch 00096: val_loss did not improve from 0.05847
#
# Epoch 00097: val_loss did not improve from 0.05847
#
# Epoch 00098: val_loss did not improve from 0.05847
#
# Epoch 00099: val_loss did not improve from 0.05847
#
# Epoch 00100: val_loss did not improve from 0.05847
#
# Epoch 00101: val_loss did not improve from 0.05847
#
# Epoch 00102: val_loss did not improve from 0.05847
#
# Epoch 00103: val_loss did not improve from 0.05847
#
# Epoch 00104: val_loss did not improve from 0.05847
#
# Epoch 00105: val_loss did not improve from 0.05847
#
# Epoch 00106: val_loss did not improve from 0.05847
#
# Epoch 00107: val_loss did not improve from 0.05847
#
# Epoch 00108: val_loss did not improve from 0.05847
#
# Epoch 00109: val_loss did not improve from 0.05847
#
# Epoch 00110: val_loss did not improve from 0.05847
#
# Epoch 00111: val_loss did not improve from 0.05847
#
# Epoch 00112: val_loss did not improve from 0.05847
#
# Epoch 00113: val_loss did not improve from 0.05847
#
# Epoch 00114: val_loss did not improve from 0.05847
#
# Epoch 00115: val_loss did not improve from 0.05847
#
# Epoch 00116: val_loss did not improve from 0.05847
#
# Epoch 00117: val_loss did not improve from 0.05847
#
# Epoch 00118: val_loss did not improve from 0.05847
#
# Epoch 00119: val_loss did not improve from 0.05847
# 975/975 [==============================] - 0s 23us/step
#
#  Accuracy : 0.9815
